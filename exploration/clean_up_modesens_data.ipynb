# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://raven-dev:iHM2CZ8pPo0SXNQd@serverlessinstance-deve.f4k8xnm.mongodb.net/?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pandas as pd

# %%
db = client.modesens
collection = db.products

# Use the find() method to query the collection.
results = collection.find()
products = pd.DataFrame(list(results))
products.to_csv('./data/modesens_products.csv',index=False )

# %%
products = pd.read_csv('./data/modesens_products.csv')
products
# Out:
#                               _id  \
# 0        651de2584c93187e5f170144
# 1        651de2584c93187e5f170145
# 2        651de2584c93187e5f170146
# 3        651de2584c93187e5f170147
# 4        651de2584c93187e5f170148
# ...                           ...
# 1124523  651de39a4c93187e5f286ca3
# 1124524  651de39a4c93187e5f286ca4
# 1124525  651de39a4c93187e5f286ca5
# 1124526  651de39a4c93187e5f286ca6
# 1124527  651de39a4c93187e5f286ca7
#
#                                                    title  \
# 0         JW ANDERSON Striped Wide Leg Shorts Flax_Multi
# 1                  JW ANDERSON Padlock Ankle Boots Green
# 2        CHIARA FERRAGNI Portacarte Golden Eye Star Pink
# 3               CHIARA FERRAGNI Portacarte Eye Star Pink
# 4              CHIARA FERRAGNI Portacarte Eye Star Black
# ...                                                  ...
# 1124523         ETRO Micro Paisley Striped Tie Navy Blue
# 1124524                          QUIKSILVER Pants Purple
# ...

# %% [markdown]
# ### Clean up Category

# %%
print(products.category.unique())
# Out:
# ['Apparel & Accessories > Clothing > Shorts'
#  'Apparel & Accessories > Shoes'
#  'Apparel & Accessories > Handbags, Wallets & Cases > Handbags'
#  'Apparel & Accessories' 'Apparel & Accessories > Jewelry > Watches'
#  'Apparel & Accessories > Clothing > Shirts & Tops'
#  'Apparel & Accessories > Clothing'
#  'Apparel & Accessories > Clothing > Outerwear > Coats & Jackets'
#  'Apparel & Accessories > Clothing > Pants'
#  'Apparel & Accessories > Jewelry > Bracelets'
#  'Luggage & Bags > Shopping Totes'
#  'Apparel & Accessories > Clothing Accessories > Belts'
#  'Apparel & Accessories > Clothing Accessories > Hats'
#  'Apparel & Accessories > Clothing > Outerwear> Vests'
#  'Apparel & Accessories > Clothing Accessories > Neckties'
#  'Apparel & Accessories > Jewelry > Earrings'
#  'Apparel & Accessories > Clothing Accessories > Sunglasses'
#  'Apparel & Accessories > Jewelry > Rings'
#  'Luggage & Bags > Messenger Bags' 'Luggage & Bags > Backpacks'
# ...

# %%
categories = {
 'Apparel & Accessories > Clothing': ["clothing", "clothing"],
 'Apparel & Accessories > Clothing > Shorts': ['bottoms', 'shorts'],
 'Apparel & Accessories > Shoes': ['footwear', 'shoes'],
 'Apparel & Accessories > Handbags, Wallets & Cases > Handbags': ['accessories', 'bags'],
 'Apparel & Accessories': ["accessories", "accessories"],
 'Apparel & Accessories > Jewelry > Watches': ['accessories', 'jewelry'],
 'Apparel & Accessories > Clothing > Shirts & Tops': ['tops', 'shirts'],
 'Apparel & Accessories > Clothing > Outerwear > Coats & Jackets': ['outerwear', 'casual jackets'],
 'Apparel & Accessories > Clothing > Pants': ['bottoms', 'pants'],
 'Apparel & Accessories > Jewelry > Bracelets': ['accessories', 'jewelry'],
 'Luggage & Bags > Shopping Totes': ['accessories', 'bags'],
 'Apparel & Accessories > Clothing Accessories > Belts': ['accessories', 'belts'],
 'Apparel & Accessories > Clothing Accessories > Hats': ['accessories', 'headwear'],
 'Apparel & Accessories > Clothing > Outerwear> Vests': ['outerwear', 'vests'],
 'Apparel & Accessories > Clothing Accessories > Neckties': ['accessories', 'ties'],
 'Apparel & Accessories > Jewelry > Earrings': ['accessories', 'jewelry'],
 'Apparel & Accessories > Clothing Accessories > Sunglasses': ['accessories', 'headwear'],
 'Apparel & Accessories > Jewelry > Rings': ['accessories', 'jewelry'],
 'Luggage & Bags > Messenger Bags': ['accessories', 'bags'],
 'Luggage & Bags > Backpacks': ['accessories', 'bags'],
 'Apparel & Accessories > Clothing > Underwear & Socks > Socks': ['footwear', 'socks'],
 'Apparel & Accessories > Jewelry > Body Jewelry': ['accessories', 'jewelry'],
 'Apparel & Accessories > Clothing Accessories > Gloves & Mittens': ['accessories', 'gloves'],
 'Apparel & Accessories > Clothing Accessories > Cufflinks': ['accessories', 'jewelry'],
 'Apparel & Accessories > Jewelry > Necklaces': ['accessories', 'jewelry'],
 'Apparel & Accessories > Jewelry': ['accessories', 'jewelry'],
 'Apparel & Accessories > Clothing Accessories > Hair Accessories': ['accessories', 'headwear'],
 'Apparel & Accessories > Clothing > Activewear': ['tops', 'activewear'],
 'Apparel & Accessories > Jewelry > Brooches & Lapel Pins': ['accessories', 'jewelry'],
 'Apparel & Accessories > Handbags, Wallets & Cases > Wallets & Money Clips': ['accessories', 'bags'],
 'Luggage & Bags > Suitcases': ['accessories', 'bags'],
 'Luggage & Bags': ['accessories', 'bags'],
 'Apparel & Accessories > Clothing Accessories > Tie Clips': ['accessories', 'jewelry'],
 'Luggage & Bags > Diaper Bags': ['accessories', 'bags'],
#  'Apparel & Accessories > Clothing > Sleepwear & Loungewear > Loungewear': []
#  'Apparel & Accessories > Clothing > Swimwear': [],
#  'Apparel & Accessories > Clothing > Underwear & Socks > Shapewear': [],
#  'Apparel & Accessories > Clothing > Sleepwear & Loungewear': [],
#  'Apparel & Accessories > Clothing > Sleepwear & Loungewear > Robes': [],
 }

# Path: clean_up_modesens_data.ipynb
products["main_category"] = products["category"].apply(lambda x: categories[x][0])
products["sub_category"] = products["category"].apply(lambda x: categories[x][1])
products.drop(columns=["category"], inplace=True)

# %%
products.sub_category.unique()
# Out:
# array(['shorts', 'shoes', 'bags', 'accessories', 'jewelry', 'shirts',
#        'clothing', 'casual jackets', 'pants', 'belts', 'headwear',
#        'vests', 'ties', 'socks', 'gloves', 'activewear'], dtype=object)

# %%
products = products.groupby("sub_category").apply(lambda x: x.sample(3000) if len(x) > 3000 else x)
products.to_csv('./data/modesens_products_sample.csv',index=False)

# %%
products = pd.read_csv('./data/modesens_products_sample.csv')

# %% [markdown]
# ### Clean up Color

# %%
# ! pip install webcolors
# import numpy as np
import webcolors
def extract_colors(text):
    valid_colors = []
    if isinstance(text, str):
        text = text.strip("['").strip("']").lower()
        colors = text.split(',')
        for c in colors:
            for cc in c.split('/'):
                cc = cc.strip()
                cc = cc.strip("'")
                if cc in webcolors.CSS3_NAMES_TO_HEX:
                    valid_colors.append(cc)
    return valid_colors

# %%
products["colors"] = products["color"].apply(extract_colors)
products.head()
# Out:
#                         _id  \
# 0  651de31d4c93187e5f214b68
# 1  651de25d4c93187e5f17217b
# 2  651de28a4c93187e5f1928d8
# 3  651de3694c93187e5f25ef17
# 4  651de2994c93187e5f19f545
#
#                                                title  \
# 0                       BMW Brown Men Optical Frames
# 1  Oakley Man Sunglasses Oo9449 Gibston Prizm Bla...
# 2                           CLARKS Casual Belt Brown
# 3    BOOGIE BABY Peek-A-Boo Puppy Blanket Light Blue
# 4          ARMANI EXCHANGE Official Store Bands Blue
#
#                                          description  \
# 0  Gendermenmain colorbrownextrano extraframe col...
# 1  Frame color: matte black; lens color: prizm bl...
# 2  Crafted from premium brown leather, this essen...
# 3  Plush velour with peek-a-boo puppy applique. c...
# 4                               Official store strap
#
#                                           image_link  sale_price  \
# 0  https://cdn.shopify.com/s/files/1/0555/5083/69...        64.0
# ...

# %% [markdown]
# ### Extract categories

# %%
category_keywords = pd.read_csv('./data/category_keywords.csv', index_col=False)
category_keywords['category'] = category_keywords['category'].apply(lambda x: x.lower())
category_keywords.head()
# Out:
#    category
# 0     jeans
# 1     pants
# 2     shirt
# 3      suit
# 4  sneakers

# %%
products['categories'] = products['description'].apply(lambda x: [keyword for keyword in category_keywords['category'].unique() if isinstance(x, str) and keyword in x])

# %%
products[products['categories'].apply(lambda x: len(x) > 0) & (products['main_category'] == 'clothing')]
# Out:
#                             _id  \
# 12586  651de2e64c93187e5f1e3b36
# 12587  651de2e34c93187e5f1e0b87
# 12589  651de29a4c93187e5f19f97b
# 12590  651de2e24c93187e5f1df1d0
# 12592  651de3564c93187e5f24c632
# ...                         ...
# 15580  651de34f4c93187e5f245319
# 15581  651de3334c93187e5f22af7b
# 15582  651de2b64c93187e5f1b7e80
# 15583  651de2ad4c93187e5f1b07a3
# 15584  651de2b64c93187e5f1b80bb
#
#                                                    title  \
# 12586             Caruso Man Suit Lead Size 44 Wool Grey
# 12587             AGNÈS B. Photograph-Print T-Shirt Blue
# 12589                       Bottega Veneta Knitwear Blue
# 12590            HARTFORD Paul Pin Point Flannel In Grey
# 12592  PT01 Crew-Neck Pullover In Wool And Angora Ble...
# ...                                                  ...
# 15580  AMIRI Broken Distressed Slim-Fit Stretch-Denim...
# 15581                                      Versace Black
# ...

# %% [markdown]
# ### Extract texture/fabric

# %%
texture_keywords = pd.read_csv('./data/texture_keywords.csv', index_col=False)
texture_keywords['texture'] = texture_keywords['texture'].apply(lambda x: x.lower())
texture_keywords.head()
# Out:
#   texture
# 0  cotton
# 1    wool
# 2    silk
# 3   linen
# 4   denim

# %%
products['textures'] = products['description'].apply(lambda x: [keyword for keyword in texture_keywords['texture'].unique() if isinstance(x, str) and keyword in x])

# %%
products[products['textures'].apply(lambda x: len(x) > 0)]
# Out:
#                             _id  \
# 2      651de28a4c93187e5f1928d8
# 3      651de3694c93187e5f25ef17
# 7      651de27a4c93187e5f182baa
# 9      651de2a64c93187e5f1a9ca9
# 10     651de28e4c93187e5f196abc
# ...                         ...
# 44111  651de3034c93187e5f1fb198
# 44112  651de26e4c93187e5f17dbf2
# 44113  651de2d34c93187e5f1d1ae4
# 44115  651de3874c93187e5f279f3d
# 44116  651de2e64c93187e5f1e2f38
#
#                                                    title  \
# 2                               CLARKS Casual Belt Brown
# 3        BOOGIE BABY Peek-A-Boo Puppy Blanket Light Blue
# 7           Stuhrling Original Aviator Quartz 43Mm Black
# 9      Fiorio Man Ties & Bow Ties Lilac Size - Silk P...
# 10     Palm Angels Signature Touch Iphone 12/12 Pro C...
# ...                                                  ...
# 44111  PETER MILLAR Excursionist Flex Reversible Vest...
# 44112  Berna Man Vest Black Size Xl Cotton, Polyamide...
# ...

# %% [markdown]
# ### Keyword extraction

# %%
# read fashion keywords
fashion_keywords = []
with open('./data/fashion_keywords_cleaned.txt') as f:
    for line in f:
        fashion_keywords.append(line.strip())

# %%
# check if fashion keywords are in the description
products["description"] = products["description"].apply(lambda x: " ".join([keyword for keyword in fashion_keywords if keyword in x]))
products.head()
# Out:
#                         _id  \
# 0  651de31d4c93187e5f214b68
# 1  651de25d4c93187e5f17217b
# 2  651de28a4c93187e5f1928d8
# 3  651de3694c93187e5f25ef17
# 4  651de2994c93187e5f19f545
#
#                                                title  \
# 0                       BMW Brown Men Optical Frames
# 1  Oakley Man Sunglasses Oo9449 Gibston Prizm Bla...
# 2                           CLARKS Casual Belt Brown
# 3    BOOGIE BABY Peek-A-Boo Puppy Blanket Light Blue
# 4          ARMANI EXCHANGE Official Store Bands Blue
#
#                                          description  \
# 0       and bra brown case extra full one own ring t
# 1                                      black matte t
# 2  accessory belt brown essential full large leat...
# 3                                         and t trim
# 4                                            strap t
#
#                                           image_link  sale_price  \
# 0  https://cdn.shopify.com/s/files/1/0555/5083/69...        64.0
# ...

# %%
# drop rows with no named categories and textures and colors
products = products[products['categories'].apply(lambda x: len(x) > 0) & products['textures'].apply(lambda x: len(x) > 0) & products['colors'].apply(lambda x: len(x) > 0)]
products
# Out:
#                             _id  \
# 9      651de2a64c93187e5f1a9ca9
# 27     651de37d4c93187e5f2711f8
# 43     651de33f4c93187e5f235f61
# 64     651de2f34c93187e5f1ed924
# 73     651de3314c93187e5f228920
# ...                         ...
# 44107  651de2b44c93187e5f1b6a43
# 44108  651de2d34c93187e5f1d1b17
# 44111  651de3034c93187e5f1fb198
# 44112  651de26e4c93187e5f17dbf2
# 44113  651de2d34c93187e5f1d1ae4
#
#                                                    title  \
# 9      Fiorio Man Ties & Bow Ties Lilac Size - Silk P...
# 27     BRUNELLO CUCINELLI Men'S Reversible Silk Pocke...
# 43     Dolce & Gabbana Eyewear Eyeglasses Transparent...
# 64               Giorgio Armani Eyeglasses Striped Brown
# 73     EDWARD ARMAH Mandala Print Silk Pocket Square ...
# ...                                                  ...
# 44107                  RICK OWENS Black Sl Vest 09 Black
# 44108                                Besilent Vests Blue
# ...

# %%
def new_description(row):
    colors = ' '.join(row['colors'])
    textures = ' '.join(row['textures'])
    if row.main_category == 'clothing':
        categories = ''.join(row['categories'])
    elif row.main_category == 'accessories':
        categories = row['categories'][0]
    else:
        categories = row.sub_category
    return colors + ' ' + textures + ' ' + categories

# %%
products['new_description'] = products.apply(new_description, axis=1)
products
# Out:
#                             _id  \
# 9      651de2a64c93187e5f1a9ca9
# 27     651de37d4c93187e5f2711f8
# 43     651de33f4c93187e5f235f61
# 64     651de2f34c93187e5f1ed924
# 73     651de3314c93187e5f228920
# ...                         ...
# 44107  651de2b44c93187e5f1b6a43
# 44108  651de2d34c93187e5f1d1b17
# 44111  651de3034c93187e5f1fb198
# 44112  651de26e4c93187e5f17dbf2
# 44113  651de2d34c93187e5f1d1ae4
#
#                                                    title  \
# 9      Fiorio Man Ties & Bow Ties Lilac Size - Silk P...
# 27     BRUNELLO CUCINELLI Men'S Reversible Silk Pocke...
# 43     Dolce & Gabbana Eyewear Eyeglasses Transparent...
# 64               Giorgio Armani Eyeglasses Striped Brown
# 73     EDWARD ARMAH Mandala Print Silk Pocket Square ...
# ...                                                  ...
# 44107                  RICK OWENS Black Sl Vest 09 Black
# 44108                                Besilent Vests Blue
# ...

# %%
# drop _id, color, textures, categories
products.drop(columns=['_id', 'color', 'textures', 'categories'], inplace=True)
products.to_csv('./data/modesens_products_sample_cleaned.csv',index=False)
